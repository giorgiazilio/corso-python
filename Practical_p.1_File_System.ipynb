# %% [markdown]
# # Practical — Working with the filesystem with `pathlib`
#
# In these exercises, use `Path` objects to inspect, search, create, and reorganize files and folders.
#
# > Replace the example paths with paths that exist on your machine.

# %% [markdown]
# ## Exercise 1 — Basic path inspection
#
# Create a `Path` object pointing to a file of your choice on your machine, then print:
#
# - whether it exists
# - its name
# - its stem
# - its suffix
# - its parent

# %%
from pathlib import Path

p = Path("/Users/giorgia/Documents/corso-python/Practical_p.1_File_System.ipynb")

print(p.exists())
print(p.name)
print(p.stem)
print(p.suffix)
print(p.parent)
# Out:
# True
# Practical_p.1_File_System.ipynb
# Practical_p.1_File_System
# .ipynb
# /Users/giorgia/Documents/corso-python

# %% [markdown]
# ## Exercise 2 — File or folder?
#
# Create two `Path` objects:
#
# - one pointing to a file
# - one pointing to a folder
#
# For each path, print whether it is a directory.

# %%
from pathlib import Path

file_path = Path("/Users/giorgia/Documents/corso-python/Practical_p.1_File_System.ipynb")
folder_path = Path("/Users/giorgia/Documents/flyback")

print(file_path.is_dir())
print(folder_path.is_dir())
# Out:
# False
# True

# %% [markdown]
# ## Exercise 3 — List all notebook files
#
# Given a folder path, print all `.ipynb` files in alphabetical order.

# %%
from pathlib import Path

folder = Path("/Users/giorgia/Documents/corso-python/")

for path in sorted(folder.glob("")):
    print(path)
# Out:
# /Users/giorgia/Documents/corso-python/Practical_p.1_File_System.ipynb
# /Users/giorgia/Documents/corso-python/Untitled.ipynb

# %% [markdown]
# ## Exercise 4 — Count files by extension
#
# Given a folder, count how many files end with:
#
# - `.py`
# - `.ipynb`
# - `.md`
#
# Print the three counts.

# %%
from pathlib import Path

folder = Path("/Users/giorgia/Documents/vecchi_script_python ")

# posso usare estensioni diverse da quelle inidicate, sostituisco .md con .txt
py_count = 0
ipynb_count = 0
txt_count = 0

for path in folder.glob("*"):
    if path.suffix == ".py":
        py_count += 1
    elif path.suffix == ".ipynb":
        ipynb_count += 1
    elif path.suffix == ".txt":
        txt_count += 1

print("py:", py_count) 
print("ipynb:", ipynb_count)
print("txt:", txt_count)
# Out:
# py: 9
# ipynb: 1
# txt: 4

# %% [markdown]
# ## Exercise 5 — Print only subfolders
#
# Given a folder, print first the paths that are directories, then the paths that are not directories

# %%
from pathlib import Path

folder = Path("/Users/giorgia/Documents/flyback")

for path in folder.glob("*"):
    if path.is_dir():
        print(path)

for path in folder.glob("*"):
    if path.is_file():
        print(path)
# Out:
# /Users/giorgia/Documents/flyback/NavigationBased_solutions
# /Users/giorgia/Documents/flyback/NOTE MONTAGGIO SWITCHER.docx
# /Users/giorgia/Documents/flyback/.DS_Store
# /Users/giorgia/Documents/flyback/Line Flyback Protocol.docx
# /Users/giorgia/Documents/flyback/Line_Flyback_Protocol_AGGIORNATO.docx
# /Users/giorgia/Documents/flyback/RIASSUNTO GESTIONE FLYBACK.docx

# %% [markdown]
# ## Exercise 6 — Recursive notebook search
#
# Search recursively inside a course folder and print all `.ipynb` files found in all subfolders.
#
# Then print the total number of notebooks found.

# %%
from pathlib import Path

course_folder = Path("/Users/giorgia/Documents/corso-python/")

count = 0

for path in course_folder.rglob("*.ipynb"):
    print(path)
    count += 1

print("Total notebooks:", count)
# Out:
# /Users/giorgia/Documents/corso-python/Practical_p.1_File_System.ipynb
# /Users/giorgia/Documents/corso-python/Untitled.ipynb
# /Users/giorgia/Documents/corso-python/.ipynb_checkpoints/Untitled-checkpoint.ipynb
# /Users/giorgia/Documents/corso-python/.ipynb_checkpoints/Practical_p.1_File_System-checkpoint.ipynb
# Total notebooks: 4

# %% [markdown]
# ## Exercise 7 — Build paths safely
#
# Starting from a base course folder, create paths for:
#
# - `lectures`
# - `practicals`
# - `data/raw`
#
# using the `/` operator, not string concatenation.
#
# Then print all of them.

# %%
from pathlib import Path

base = Path("/Users/giorgia/Documents/course")

lectures = base / "lectures"
practicals = base / "practical"
raw_data = base / "data" / "raw"

print(lectures)
print(practicals)
print(raw_data)
# Out:
# /Users/giorgia/Documents/course/lectures
# /Users/giorgia/Documents/course/practical
# /Users/giorgia/Documents/course/data/raw

# %% [markdown]
# ## Exercise 8 — Create a nested folder structure
#
# Create the following structure inside a base folder:
#
# - `results/`
# - `results/figures/`
# - `results/tables/`
#
# Do it programmatically with `mkdir()`.

# %%
from pathlib import Path

base = Path("/Users/giorgia/Documents/course")

figures_path = base / "results" / "figures"
tables_path = base / "results" / "tables"

figures_path.mkdir(parents=True, exist_ok=True)
tables_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Exercise 9 — Move matching files
#
# Inside a folder, move all `.txt` files into a subfolder called `text_files`.
#
# If the destination folder does not exist, create it first.

# %%
from pathlib import Path

folder = Path("/Users/giorgia/Documents/vecchi_script_python ")
destination = folder / "text_files"

destination.mkdir(parents=True, exist_ok=True)

for path in folder.glob("*.txt"):
    if not path.is_dir(): 
    
        path.rename(destination / path.name)

# %% [markdown]
# ## Exercise 10 — Organize files by prefix
#
# Suppose a folder contains files with names such as:
#
# - `sub01_session1_data.csv`
# - `sub01_session2_data.csv`
# - `sub02_session1_data.csv`
#
# Write code that moves each file into a folder structure like:
#
# - `sub01/session1/`
# - `sub01/session2/`
# - `sub02/session1/`
#
# Use the filename (without extension) and split it on `"_"`.

# %%
from pathlib import Path

# Creato una cartella dummy con dei finiti file per vedere se lo script funziona
test_folder = Path("/Users/giorgia/Documents/test_data")
test_folder.mkdir(exist_ok=True)

(test_folder / "sub01_session1_data.csv").touch()
(test_folder / "sub01_session2_data.csv").touch()
(test_folder / "sub02_session1_data.csv").touch()

print("File di test creati")
# Out:
# File di test creati

# %%
from pathlib import Path

data_folder = Path("/Users/giorgia/Documents/test_data")
new_root = Path("/Users/giorgia/Documents/test_data_organized")
new_root.mkdir(exist_ok=True)

for file in data_folder.glob("*.csv"):
    subject, session, _ = file.stem.split("_")
    target_folder = new_root / subject / session
    target_folder.mkdir(exist_ok=True, parents=True)
    file.rename (target_folder / file.name)

# %% [markdown]
# ## Exercise 11 — Build a file inventory
#
# Given a folder, create a list of dictionaries where each dictionary contains:
#
# - `"name"`
# - `"suffix"`
# - `"is_dir"`
# - `"parent"`
#
# for every path in the folder.
#
# Then print the resulting list.

# %%
from pathlib import Path

folder = Path("/Users/giorgia/Documents/corso-python")
inventory = []

for path in folder.glob("*"):
    info = {
        "name": path.name,
        "suffix": path.suffix,
        "is_dir": path.is_dir(),
        "parent": str(path.parent)
    }
    inventory.append(info)

print(inventory)
# Out:
# [{'name': 'LICENSE', 'suffix': '', 'is_dir': False, 'parent': '/Users/giorgia/Documents/corso-python'}, {'name': 'Practical_p.1_File_System.ipynb', 'suffix': '.ipynb', 'is_dir': False, 'parent': '/Users/giorgia/Documents/corso-python'}, {'name': 'Untitled.ipynb', 'suffix': '.ipynb', 'is_dir': False, 'parent': '/Users/giorgia/Documents/corso-python'}, {'name': 'README.md', 'suffix': '.md', 'is_dir': False, 'parent': '/Users/giorgia/Documents/corso-python'}, {'name': '.ipynb_checkpoints', 'suffix': '', 'is_dir': True, 'parent': '/Users/giorgia/Documents/corso-python'}, {'name': '.git', 'suffix': '', 'is_dir': True, 'parent': '/Users/giorgia/Documents/corso-python'}]

# %% [markdown]
# ## Exercise 12 —  Only files, sorted by suffix
#
# Given a folder:
#
# 1. collect only the files, not the subfolders
# 2. sort them by suffix
# 3. print their names

# %%
from pathlib import Path

folder = Path("/Users/giorgia/Documents/corso-python")

files_only = []

for path in folder.glob("*"):
    if not path.is_dir():
        files_only.append(path)

for path in sorted(files_only, key=lambda p: p.suffix):
    print(path.name)
# Out:
# LICENSE
# Practical_p.1_File_System.ipynb
# Untitled.ipynb
# README.md
